# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!

# %%
# Out:
#   File "<ipython-input-5-60fa99082b02>", line 1
#     git push origin master
#            ^
# SyntaxError: invalid syntax
